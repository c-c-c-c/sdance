# %% [markdown]
# <a href="https://colab.research.google.com/github/c-c-c-c/sdance/blob/master/filter_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# フィルターテスト

# %%
from pathlib import Path
from google.colab import drive
import datetime as dt
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
# マウントする

# drive.mount(str(DRIVE_DIR))

HOME_DIR = Path('/content/drive/My Drive/filter_test')


INPUT_CSV_DIR = HOME_DIR / 'input_csv'

# df = pd.read_csv( str( INPUT_CSV_DIR/"chosei.csv" ) )
df = pd.read_csv( str( INPUT_CSV_DIR/"honmei.csv" ) )

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1    0    1   2    3
# 0             0             0    1  105  81  191
# 1             1             0    2  107  81  216
# 2             2             0    3  105  80  219
# 3             3             0    4  104  81  204
# 4             4             0    5  105  81  187
# ..          ...           ...  ...  ...  ..  ...
# 506         506             0  507  117  71  184
# 507         507             0  508  116  70  161
# 508         508             0  509  117  67  157
# 509         509             0  510  117  67  153
# 510         510             0  511  113  68  142
#
# [511 rows x 6 columns]

# %%
df = df.iloc[ :, 2:]

# %%
df
# Out:
#        0    1   2    3
# 0      1  105  81  191
# 1      2  107  81  216
# 2      3  105  80  219
# 3      4  104  81  204
# 4      5  105  81  187
# ..   ...  ...  ..  ...
# 506  507  117  71  184
# 507  508  116  70  161
# 508  509  117  67  157
# 509  510  117  67  153
# 510  511  113  68  142
#
# [511 rows x 4 columns]

# %%
# fig = plt.figure(figsize=(90,20))
from matplotlib import pyplot as plt
plt.figure(figsize=(20,8))
plt.plot(
    df.iloc[ :, 0].tolist(),
    df.iloc[ :, 1].tolist())

plt.plot(
    df.iloc[ :, 0].tolist(),
    df.iloc[ :, 2].tolist())

# plt.plot(
#     df.iloc[ :, 0].tolist(),
#     df.iloc[ :, 3].tolist())

plt.show()

#  figsize=(10,10),dpi=200

# %%
def lpf(a, w):
    v0 = np.array([1, 4, 6, 4, 1])/16.0
    y1 = np.convolve(a, v0, mode='same')

    v1 = np.ones(w)/w
    y2 = np.convolve(y1, v1, mode='same')

    return y2

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(20,8))
plt.plot(
    df.iloc[ :, 0].tolist(),
    df.iloc[ :, 1].tolist())

plt.plot(
    df.iloc[ :, 0].tolist(),
    lpf( df.iloc[ :, 1].tolist(), 10))

plt.plot(
    df.iloc[ :, 0].tolist(),
    lpf( df.iloc[ :, 1].tolist(), 40))

plt.show()

# %%
def hpf(a):
    v5 = np.array([1, 4, 6, 4, 1])/16.0
    y1 = np.convolve(a, v5, mode='same')

    v05 = np.ones( 5)/5.0
    v07 = np.ones( 7)/7.0
    v11 = np.ones(11)/11.0
    v15 = np.ones(15)/15.0
    v21 = np.ones(21)/21.0
    v31 = np.ones(31)/31.0

    y2 = np.convolve(y1, v05, mode='same')
    y3 = np.convolve(y1, v15, mode='same')

    y4 = y2 - y3

    return y4

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(20,8))
plt.plot(
    df.iloc[ :, 0].tolist(),
    df.iloc[ :, 1].tolist())

plt.plot(
    df.iloc[ :, 0].tolist(),
    hpf( df.iloc[ :, 1].tolist()))

plt.show()

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(20,8))
plt.plot(
    df.iloc[ :, 0].tolist(),
    df.iloc[ :, 2].tolist())

plt.plot(
    df.iloc[ :, 0].tolist(),
    lpf( df.iloc[ :, 2].tolist(), 10))

plt.plot(
    df.iloc[ :, 0].tolist(),
    lpf( df.iloc[ :, 2].tolist(), 40))

plt.show()

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(20,8))
plt.plot(
    df.iloc[ :, 0].tolist(),
    df.iloc[ :, 3].tolist())

plt.plot(
    df.iloc[ :, 0].tolist(),
    lpf( df.iloc[ :, 3].tolist(), 5))

plt.plot(
    df.iloc[ :, 0].tolist(),
    lpf( df.iloc[ :, 3].tolist(), 40))

plt.show()

# %%
# from matplotlib import pyplot as plt
# plt.figure(figsize=(20,8))
# plt.plot(
#     df.iloc[ :, 0].tolist(),
#     df.iloc[ :, 3].tolist())

# plt.plot(
#     df.iloc[ :, 0].tolist(),
#     hpf( df.iloc[ :, 3].tolist()))

# plt.show()
